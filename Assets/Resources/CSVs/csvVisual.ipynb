# %%
import pandas as pd

# %%
df = pd.read_csv("Detailed Ingredient List - Do Stats Affect Abilities Currently.csv")  # Replace with your file path
df
# Out:
#          Attack Type  SOUR_Duration         SALTY_CriticalStrike  BITTER_Size  \
# 0              Melee          False  Not Implemented In Collider         True
# 1             Charge           True  Not Implemented In Collider        False
# 2  Single Projectile           True  Not Implemented In Collider         True
# 3  Double Projectile           True  Not Implemented In Collider         True
# 4      Centered Zone           True  Not Implemented In Collider         True
# 5          Shot Zone           True  Not Implemented In Collider         True
#
#    SWEET_Speed  Column 1  Base Crit  Base Speed  Base Cooldown  Inflictions  \
# 0        False       NaN        NaN         NaN            NaN          NaN
# 1         True       NaN        NaN         NaN            NaN          NaN
# 2         True       NaN        NaN         NaN            NaN          NaN
# 3         True       NaN        NaN         NaN            NaN          NaN
# ...

# %%
df = pd.read_csv("Detailed Ingredient List - Detailed Current Flavor Ingredients.csv")  # Replace with your file path
df
# Out:
#      Ingredient     Flavor 1 Operation 1  Quality 1      Flavor 2 Operation 2  \
# 0        Carrot  Bitter_SIZE         Add          1           NaN         NaN
# 1          Leek  Bitter_SIZE         Add          2  Spiky_DAMAGE         Add
# 2        Pepper  Sweet_SPEED         Add          1    Spicy_BURN         Add
# 3  Super Carrot  Sweet_SPEED         Add          3           NaN         NaN
# 4    Super Tofu  Sweet_SPEED         Add         10           NaN         NaN
# 5          Tofu  Sweet_SPEED         Add          5           NaN         NaN
#
#    Quality 2
# 0        NaN
# 1        2.0
# 2        5.0
# 3        NaN
# 4        NaN
# 5        NaN

# %%
df = pd.read_csv("Detailed Ingredient List - Detailed Current Ability Ingredients.csv")  # Replace with your file path
df
# Out:
#   Ingredient Name            Enemy       Ability Type  The Base Duration  \
# 0   Default Spoon             None        Melee Swing                  0
# 1     Lettucs Ear         Flettuce             Charge                  0
# 2     Lizard Tail        Hopshroom  Single Projectile                  3
# 3    Fire Biscuit        Habaperro    Dual Projectile                  3
# 4           Spuds         Taterhop        Player Zone                  1
# 5     Eye Of Newt  Purple Flettuce          Shot Zone                  1
#
#    The Base Size  The Base Crit  The Base Speed  The Base Cooldown  \
# 0              5              0               0                0.5
# 1              7              0               0                1.0
# 2              1              1               5                0.5
# 3              1              1               5                0.5
# 4              1              1               1                1.0
# ...
